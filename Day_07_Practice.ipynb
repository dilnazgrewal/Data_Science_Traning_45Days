# %%
import numpy as np

# %%
marks = np.array([[78, 85, 80, 90],
                  [65, 70, 75, 68],
                  [88, 92, 95, 91],
                  [55, 60, 58, 62],
                  [72, 76, 70, 80],
                  [90, 89, 94, 96]])

# %%
print(marks)
# Out:
# [[78 85 80 90]
#  [65 70 75 68]
#  [88 92 95 91]
#  [55 60 58 62]
#  [72 76 70 80]
#  [90 89 94 96]]

# %%
print(marks.shape)
# Out:
# (6, 4)

# %%
print(marks.size)
# Out:
# 24

# %%
print(marks.ndim)
# Out:
# 2

# %%
print(marks.dtype)
# Out:
# int64

# %%
print(marks[0])
# Out:
# [78 85 80 90]

# %%
print(marks[1])
# Out:
# [65 70 75 68]

# %%
print(marks[5])
# Out:
# [90 89 94 96]

# %%
print(marks[2][2])
# Out:
# 95

# %%
print(marks[3][3])
# Out:
# 62

# %%
print(marks[:,0])
# Out:
# [78 65 88 55 72 90]

# %%
print(marks[:,1])
# Out:
# [85 70 92 60 76 89]

# %%
print(marks[:,2])
# Out:
# [80 75 95 58 70 94]

# %%
print(marks[:,3:])
# Out:
# [[90]
#  [68]
#  [91]
#  [62]
#  [80]
#  [96]]

# %%
print(marks[:2][:2])
# Out:
# [[78 85 80 90]
#  [65 70 75 68]]

# %%
print(marks[:3][:3])
# Out:
# [[78 85 80 90]
#  [65 70 75 68]
#  [88 92 95 91]]

# %%
print(marks[-2:][-2:])
# Out:
# [[72 76 70 80]
#  [90 89 94 96]]

# %%
print(marks[:,1:3])
# Out:
# [[85 80]
#  [70 75]
#  [92 95]
#  [60 58]
#  [76 70]
#  [89 94]]

# %%
print(marks[1:4])
# Out:
# [[65 70 75 68]
#  [88 92 95 91]
#  [55 60 58 62]]

# %%
print(marks[1:4, 1:3])
# Out:
# [[70 75]
#  [92 95]
#  [60 58]]

# %%
print(marks[1::2])
# Out:
# [[65 70 75 68]
#  [55 60 58 62]
#  [90 89 94 96]]

# %%
print(marks[::-1])
# Out:
# [[90 89 94 96]
#  [72 76 70 80]
#  [55 60 58 62]
#  [88 92 95 91]
#  [65 70 75 68]
#  [78 85 80 90]]

# %%
print(marks[:, ::-1])
# Out:
# [[90 80 85 78]
#  [68 75 70 65]
#  [91 95 92 88]
#  [62 58 60 55]
#  [80 70 76 72]
#  [96 94 89 90]]

# %%
stocks = np.array([
    [20, 25, 22, 30],
    [35, 40, 38, 42],
    [15, 18, 20, 25]
])

# %%
print(stocks)
# Out:
# [[20 25 22 30]
#  [35 40 38 42]
#  [15 18 20 25]]

# %%
print(stocks.shape)
# Out:
# (3, 4)

# %%
print(stocks.size)
# Out:
# 12

# %%
print(stocks.ndim)
# Out:
# 2

# %%
print(stocks.dtype)
# Out:
# int64

# %%
print(stocks[0])
# Out:
# [20 25 22 30]

# %%
print(stocks[1])
# Out:
# [35 40 38 42]

# %%
print(stocks[2])
# Out:
# [15 18 20 25]

# %%
print(stocks[:,0])
# Out:
# [20 35 15]

# %%
print(stocks[:,3])
# Out:
# [30 42 25]

# %%
print(stocks[0,1])
# Out:
# 25

# %%
print(stocks[1,2])
# Out:
# 38

# %%
print(stocks[2,3])
# Out:
# 25

# %%
print(stocks[:2])
# Out:
# [[20 25 22 30]
#  [35 40 38 42]]

# %%
print(stocks[:,1:])
# Out:
# [[25 22 30]
#  [40 38 42]
#  [18 20 25]]

# %%
print(stocks[0:2,1:3])
# Out:
# [[25 22]
#  [40 38]]

# %%
print(stocks[::-1])
# Out:
# [[15 18 20 25]
#  [35 40 38 42]
#  [20 25 22 30]]

# %%
print(stocks[:,::-1])
# Out:
# [[30 22 25 20]
#  [42 38 40 35]
#  [25 20 18 15]]
